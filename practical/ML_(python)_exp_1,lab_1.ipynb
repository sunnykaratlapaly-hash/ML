# %% [markdown]
# **PROGRAM : " 1 "**

# %% [markdown]
# 1.Write a Python program to declare variables of type int, float, string, and boolean, and display their values along with their data types.

# %%
age = 19
height = 169.3
name = "abhay"
is_enrolled = True

print(f"Value: {age}, Type: {type(age)}")
print(f"Value: {height}, Type: {type(height)}")
print(f"Value: {name}, Type: {type(name)}")
print(f"Value: {is_enrolled}, Type: {type(is_enrolled)}")
# Out:
# Value: 19, Type: <class 'int'>
# Value: 169.3, Type: <class 'float'>
# Value: abhay, Type: <class 'str'>
# Value: True, Type: <class 'bool'>

# %% [markdown]
# 2.Write a program to check the data type of different variables using the type() function

# %%
var1 = 100
var2 = 98.6
var3 = "Python"
var4 = False
var5 = [1, 2, 3]

print("Type of var1:", type(var1))
print("Type of var2:", type(var2))
print("Type of var3:", type(var3))
print("Type of var4:", type(var4))
print("Type of var5:", type(var5))
# Out:
# Type of var1: <class 'int'>
# Type of var2: <class 'float'>
# Type of var3: <class 'str'>
# Type of var4: <class 'bool'>
# Type of var5: <class 'list'>

# %% [markdown]
#  3.Modify the values of the variables and observe how their data types change.

# %%
x = 25
print("Value:", x, "| Type:", type(x))

x = 25.5
print("Value:", x, "| Type:", type(x))

x = "Twenty Five"
print("Value:", x, "| Type:", type(x))

x = True
print("Value:", x, "| Type:", type(x))
# Out:
# Value: 25 | Type: <class 'int'>
# Value: 25.5 | Type: <class 'float'>
# Value: Twenty Five | Type: <class 'str'>
# Value: True | Type: <class 'bool'>

# %% [markdown]
#  4.Create your own variables representing a student's details and print their values and data types.

# %%
student_name = "Abhay"
roll_number = 2520030353
gpa = 8.75
is_passed = True

print("Student Name:", student_name, "->", type(student_name))
print("Roll Number:", roll_number, "->", type(roll_number))
print("GPA:", gpa, "->", type(gpa))
print("Passed Status:", is_passed, "->", type(is_passed))
# Out:
# Student Name: Abhay -> <class 'str'>
# Roll Number: 2520030353 -> <class 'int'>
# GPA: 8.75 -> <class 'float'>
# Passed Status: True -> <class 'bool'>

# %% [markdown]
# **PROGRAM : " 2 "**

# %% [markdown]
# 1.Write a Python program to demonstrate arithmetic operators.

# %%
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Exponentiation: 50625

# %% [markdown]
# 2.Write a program to demonstrate comparison operators using two numbers.

# %%
x = 20
y = 10

print("x == y:", x == y)
print("x != y:", x != y)
print("x > y:", x > y)
print("x < y:", x < y)
print("x >= y:", x >= y)
print("x <= y:", x <= y)
# Out:
# x == y: False
# x != y: True
# x > y: True
# x < y: False
# x >= y: True
# x <= y: False

# %% [markdown]
#  3.Write a program to demonstrate logical operators (and, or, not).

# %%
p = True
q = False

print("p AND q:", p and q)
print("p OR q:", p or q)
print("NOT p:", not p)
# Out:
# p AND q: False
# p OR q: True
# NOT p: False

# %% [markdown]
# 4.Write a program to determine whether a student is eligible for placement based on CGPA and attendance using logical operators.bold text

# %%
cgpa = 8.2
attendance = 80

eligible = (cgpa >= 7.5) and (attendance >= 75)

print("CGPA:", cgpa)
print("Attendance:", attendance)
print("Eligible for Placement:", eligible)
# Out:
# CGPA: 8.2
# Attendance: 80
# Eligible for Placement: True

# %% [markdown]
# **PROGRAM : " 3 "**

# %%
model_name = "Logistic Regression"
accuracy = 0.87345

# Old, clunky way (avoid this):
print("Accuracy of " + model_name + " is " + str(accuracy))

# f-string way (use this):
print(f"Accuracy of {model_name} is {accuracy}")

# ':.3f' inside the braces rounds a float to 3 decimal places -
# you will use this in almost every experiment to print clean metrics.
print(f"Accuracy of {model_name} is {accuracy:.3f}")
# Out:
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.87345
# Accuracy of Logistic Regression is 0.873

# %% [markdown]
# **PROGRAM : " 4 "**

# %% [markdown]
# 1.Write a Python program to create a list and access its elements using indexing.

# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]
print("Original list:", fruits)
print("-" * 30)
print("First element (index 0):", fruits[0])
print("Third element (index 2):", fruits[2])
print("Last element (index -1):", fruits[-1])
print("Second to last element (index -2):", fruits[-2])
print("First three elements (index 0 to 2):", fruits[0:3])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'date', 'elderberry']
# ------------------------------
# First element (index 0): apple
# Third element (index 2): cherry
# Last element (index -1): elderberry
# Second to last element (index -2): date
# First three elements (index 0 to 2): ['apple', 'banana', 'cherry']

# %% [markdown]
# 2.Write a program to display the first, second, and last elements of a list.

# %%
numbers = [10, 20, 30, 40, 50]

first_element = numbers[0]
second_element = numbers[1]
last_element = numbers[-1]

print("First element:", first_element)
print("Second element:", second_element)
print("Last element:", last_element)
# Out:
# First element: 10
# Second element: 20
# Last element: 50

# %% [markdown]
# 3.Write a program to demonstrate list slicing.

# %%
letters = ["a", "b", "c", "d", "e", "f", "g"]

print("Elements from index 1 to 3:", letters[1:4])
print("First 3 elements:", letters[:3])
print("Elements from index 3 onward:", letters[3:])
print("Every second element:", letters[::2])
# Out:
# Elements from index 1 to 3: ['b', 'c', 'd']
# First 3 elements: ['a', 'b', 'c']
# Elements from index 3 onward: ['d', 'e', 'f', 'g']
# Every second element: ['a', 'c', 'e', 'g']

# %% [markdown]
# 4.Write a program to add a new element to an existing list using the append() method.

# %%
colors = ["red", "green", "blue"]
print("Original list:", colors)

colors.append("yellow")

print("Updated list:", colors)
# Out:
# Original list: ['red', 'green', 'blue']
# Updated list: ['red', 'green', 'blue', 'yellow']

# %% [markdown]
# 5.Write a program to display the total number of elements in a list.

# %%
cities = ["New York", "London", "Tokyo", "Paris", "Sydney"]

total_elements = len(cities)

print("List of cities:", cities)
print("Total number of elements:", total_elements)
# Out:
# List of cities: ['New York', 'London', 'Tokyo', 'Paris', 'Sydney']
# Total number of elements: 5

# %% [markdown]
# **PROGRAM : " 5 "**

# %% [markdown]
# 1.Write a Python program to create a dictionary and display all its key-value pairs.

# %%
person = {"name": "Alice", "age": 25, "city": "New York"}
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'New York'}

# %% [markdown]
# 2.Write a program to access the value associated with a specific key in a dictionary.

# %%
student = {"id": 101, "name": "Bob", "grade": "A"}
key_to_access = "name"
print(student[key_to_access])
# Out:
# Bob

# %% [markdown]
# 3.Write a program to iterate through a dictionary using the items() method.

# %%
scores = {"Math": 90, "Science": 85, "English": 92}

for subject, score in scores.items():
    print(f"{subject}: {score}")
# Out:
# Math: 90
# Science: 85
# English: 92

# %% [markdown]
# 4.Write a program to store different machine learning models in a dictionary and display their names and objects.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

ml_models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Support Vector Machine": SVC()
}

for name, model_obj in ml_models.items():
    print(f"Model Name: {name} | Object: {model_obj}")
# Out:
# Model Name: Logistic Regression | Object: LogisticRegression()
# Model Name: Random Forest | Object: RandomForestClassifier()
# Model Name: Support Vector Machine | Object: SVC()

# %% [markdown]
# **PROGRAM : " 6 "**

# %% [markdown]
# 1.Write a Python program to classify a student's CGPA into High, Mid, or Low categories using if-elif-else.

# %%
cgpa = 8.2

if cgpa >= 8.0:
    category = "High"
elif cgpa >= 6.0:
    category = "Mid"
else:
    category = "Low"

print(f"CGPA: {cgpa}, Category: {category}")
# Out:
# CGPA: 8.2, Category: High

# %% [markdown]
# 2.Write a program to check whether missing values are present in a dataset using conditional statements.

# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Score': [85, None, 92]
})

if df.isnull().values.any():
    print("Missing values are present in the dataset.")
else:
    print("No missing values found in the dataset.")
# Out:
# Missing values are present in the dataset.

# %% [markdown]
# 3.Write a program to determine whether a student is eligible for placement based on CGPA.

# %%
cgpa = 7.5
min_required_cgpa = 6.5

if cgpa >= min_required_cgpa:
    print("Student is eligible for placement.")
else:
    print("Student is not eligible for placement.")
# Out:
# Student is eligible for placement.

# %% [markdown]
# 4.Write a program that uses if-elif-else to assign grades based on marks.

# %%
marks = 85

if marks >= 90:
    grade = "A+"
elif marks >= 80:
    grade = "A"
elif marks >= 70:
    grade = "B"
elif marks >= 60:
    grade = "C"
elif marks >= 50:
    grade = "D"
else:
    grade = "F"

print(f"Marks: {marks}, Grade: {grade}")
# Out:
# Marks: 85, Grade: A

# %% [markdown]
# **PROGRAM : " 7 "**

# %% [markdown]
# 1.Write a Python program to display all elements in a list using a for loop.

# %%
numbers = [10, 20, 30, 40, 50]

for item in numbers:
    print(item)
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# 2.Write a program to calculate the average of numbers stored in a list.

# %%
numbers = [12, 45, 67, 23, 89, 34]
total_sum = 0

for num in numbers:
    total_sum += num

average = total_sum / len(numbers)
print(f"Average: {average}")
# Out:
# Average: 45.0

# %% [markdown]
# 3.Write a program to display only the values greater than a given threshold using a loop.

# %%
numbers = [15, 82, 43, 91, 27, 60]
threshold = 50

for num in numbers:
    if num > threshold:
        print(num)
# Out:
# 82
# 91
# 60

# %% [markdown]
# 4.Write a program to find the maximum and minimum values in a list using loops.

# %%
numbers = [45, 12, 89, 3, 67, 34]

max_val = numbers[0]
min_val = numbers[0]

for num in numbers[1:]:
    if num > max_val:
        max_val = num
    if num < min_val:
        min_val = num

print(f"Maximum value: {max_val}")
print(f"Minimum value: {min_val}")
# Out:
# Maximum value: 89
# Minimum value: 3

# %% [markdown]
# 5.Write a program to count the number of elements satisfying a given condition using a loop.

# %%
numbers = [12, 7, 18, 5, 22, 9, 14]
count = 0

for num in numbers:
    if num % 2 == 0:
        count += 1

print(f"Count of even numbers: {count}")
# Out:
# Count of even numbers: 4
